# %% [markdown]
# Model integration With Gemini

# %% [markdown]
# Streaming and Batch

# %%
Steaming

Most Models can stream their output content while it us being generated. By displaying outpit progressively, 
streaming significantly improves user experience, particularly for the longer responses. Calling stream()
 return an iterator that yeilds output chunks as they are produced.

 We can use a loop to process each chunk in real-time.

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import HumanMessage

# Set your API key (get this from Google AI Studio)
os.environ["GEMINI_API_KEY"] = "AIzaSyAZaF4qMHYpzlpxTULsiklNGpHNE-p07So"

# Initialize the model (using gemini-3.5-flash, the engine behind Antigravity)
llm = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite",
    temperature=0.7,
    max_retries=2
)
